# %% [markdown]
# <img src='https://data.actris.eu/static/img/actris-dc-logo.png' width=400 align=right>
#
# # Equivalent black carbon (eBC)

# %% [markdown]
# Equivalent black carbon (eBC) is used to describe carbon mass derived from the aerosol absorption coefficient. The aerosol absorption coefficient is measured using filter absorption photometers, such as AE33, MAAP, CLAP etc. In this example eBC is calculated using the aerosol absorption coefficient at 637 nm. If no such wavelength exists, an extrapolation using the two closest wavelengths and the Ångström exponent (AAE) is performed. The aerosol absorption coefficient is then devided by a mass absorption coefficient (MAC) to aqcuire equivalent black carbon mass concentration (µg/m$^3$)
#
# A mass absorption coefficient (MAC) value of 10.0 m$^2$ g$^{-1}$ (geometric standard deviation = 1.33) at a wavelength of 637 nm can be considered to be representative of the mixed boundary layer at European background sites, where BC is expected to be internally mixed to a large extent. [1]
#
# ##### References:
#
# [1] M. Zanatta, M. Gysel, N. Bukowiecki, T. Müller, E. Weingartner, H. Areskoug, M. Fiebig, K.E. Yttri, N. Mihalopoulos, G. Kouvarakis, D. Beddows, R.M. Harrison, F. Cavalli, J.P. Putaud, G. Spindler, A. Wiedensohler, A. Alastuey, M. Pandolfi, K. Sellegri, E. Swietlicki, J.L. Jaffrezo, U. Baltensperger, P. Laj, A European aerosol phenomenology-5: Climatology of black carbon optical properties at 9 regional background sites across Europe,
# Atmospheric Environment, Volume 145, 2016, Pages 346-364, ISSN 1352-2310, https://doi.org/10.1016/j.atmosenv.2016.09.035.

# %%
import xarray as xr 
import netCDF4 as nc 
import threddsclient
import numpy as np
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ### Access NRT filter absorption photometer data

# %%
# Get the ACTRIS NRT thredds catalog
all_opendap_urls = threddsclient.opendap_urls('https://thredds.nilu.no/thredds/catalog/actris_nrt/catalog.xml')

# Get all filter absorption photometer opendap urls and then choose level NRT (1.5) files. 
# This code also works with level 2 files. 
fap_opendap_urls = [x for x in all_opendap_urls if 'filter_absorption_photometer' in x]
fap_opendap_urls = [x for x in fap_opendap_urls if 'lev1.5' in x]
print('All NRT filter_absorption_photometer datasets with opendap protocol: \n',fap_opendap_urls)
# Out:
# All NRT filter_absorption_photometer datasets with opendap protocol:
#  ['https://thredds.nilu.no/thredds/dodsC/actris_nrt/AT0034G.20260128110000.20260428105410.filter_absorption_photometer...3mo.1h.AT04L_Magee_AE33_41_NRT.AT04L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/BE0007R.20260128110000.20260428103616.filter_absorption_photometer...3mo.1h.BE03L_Magee_AE36_VIE_pm10_NRT.BE03L_AE36_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/CH0001G.20260128110000.20260428111400.filter_absorption_photometer...3mo.1h.CH02L_Magee_AE33_JFJ_NRT.CH02L_aethalometer_ae33_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/CZ0003R.20260128110000.20260428111410.filter_absorption_photometer...3mo.1h.CZ06L_Magee_AE33_Czechglobe_NRT.CZ06L_abs_coef_AE33_v1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/CZ0004B.20260122110000.20260422111410.filter_absorption_photometer...3mo.1h.CZ03L_Magee_AE33_Suchdol_NRT.CZ06L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/DE0044R.20251203170000.20260303160006.filter_absorption_photometer...3mo.1h.DE08L_Thermo_5012_SN137_NRT.DE08L_MAAP_5012.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/DE0044R.20260128110000.20260428111416.filter_absorption_photometer...3mo.1h.DE08L_Magee_AE33_Melpitz_NRT.DE08L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0019U.20260128110000.20260428110606.filter_absorption_photometer...3mo.1h.ES05L_Magee_AE33_sn143_NRT.ES05L_AE33_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0023R.20260128110000.20260428111510.filter_absorption_photometer...3mo.1h.FI03L_Magee_AE36_VAR_NRT.FI03L_ae36_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0038U.20260128110000.20260428111557.filter_absorption_photometer...3mo.1h.FI01L_Thermo_5012_KUM_NRT.FI01L_MAAP_5012.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0050R.20260128110000.20260428111421.filter_absorption_photometer...3mo.1h.FI03L_Magee_AE33_NRT.FI03L_aeth_control_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0050R.20260128110000.20260428111601.filter_absorption_photometer...3mo.1h.FI03L_Thermo_5021_HYY_NRT.FI03L_MAAP_5012.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0063R.20260128110000.20260428111426.filter_absorption_photometer...3mo.1h.FI07L_Magee_AE33_Puijo_SMEARIV_NRT.FI07L_abs_coef_V1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0096G.20260209080000.20260428110611.filter_absorption_photometer...3mo.1h.FI01L_Magee_AE33_PAL_NRT.FI01L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FR0020R.20260128110000.20260428111431.filter_absorption_photometer...3mo.1h.FR01L_Magee_AE33_SIR_pm10_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/GR0100B.20260128110000.20260428110621.filter_absorption_photometer...3mo.1h.GR05L_Magee_AE33_DEM_dry_NRT.GR05L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/IT0009R.20260128120000.20260428111437.filter_absorption_photometer...3mo.1h.IT06L_Magee_AE33_CMN_NRT.IT06L_Magee_AE33_CMN_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/IT0022C.20260302100000.20260428110909.filter_absorption_photometer...8w.1h.IT06L_Magee_AE33_BO_NRT.IT06L_AE33_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/NO0002R.20260122110000.20260422081442.filter_absorption_photometer...3mo.1h.NO01L_Magee_AE33_BIR_dry_NRT.NO01L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/NO0059G.20260313110000.20260428104205.filter_absorption_photometer...46d.1h.NO01L_Magee_AE33_TRL_dry_NRT.NO01L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/PL0006R.20260128110000.20260428112427.filter_absorption_photometer...3mo.1h.PL04L_Magee_AE33_Raciborz_NRT.PL04L_abs_coef_AE33_v1_ECACv1.lev1.5.nc', 'https:// ...

# %%
# For this example only one opendap_url is used. 
# If you wish to use another dataset, change the number in the brackets.
opendap_url = fap_opendap_urls[3]
opendap_url
# Out:
# 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/CZ0003R.20260128110000.20260428111410.filter_absorption_photometer...3mo.1h.CZ06L_Magee_AE33_Czechglobe_NRT.CZ06L_abs_coef_AE33_v1.lev1.5.nc'

# %%
# Open and show dataset with xarray 
ds_xr = xr.open_dataset(opendap_url)
ds_xr
# Out:
# <xarray.Dataset> Size: 622kB
# Dimensions:                                               (time: 1582,
#                                                            tbnds: 2,
#                                                            metadata_time: 1,
#                                                            Location: 1,
#                                                            pressure_qc_flags: 1,
#                                                            temperature_qc_flags: 1,
#                                                            Wavelength: 7,
#                                                            aerosol_absorption_coefficient_amean_qc_flags: 1,
#                                                            aerosol_absorption_coefficient_prec1587_qc_flags: 1,
#                                                            aerosol_absorption_coefficient_perc8413_qc_flags: 1)
# Coordinates:
#   * time                                                  (time) datetime64[ns] 13kB ...
#   * metadata_time                                         (metadata_time) datetime64[ns] 8B ...
#   * Location                                              (Location) |S64 64B ...
#   * Wavelength                                            (Wavelength) float64 56B ...
# Dimensions without coordinates: tbnds, pressure_qc_flags, temperature_qc_flags,
#                                 aerosol_absorption_coefficient_amean_qc_flags,
#                                 aerosol_absorption_coefficient_prec1587_qc_flags,
#                                 aerosol_absorption_coefficient_perc8413_qc_flags
# Data variables: (12/17)
#     time_bnds                                             (time, tbnds) datetime64[ns] 25kB ...
#     metadata_time_bnds                                    (metadata_time, tbnds) datetime64[ns] 16B ...
#     pressure_qc                                           (Location, pressure_qc_flags, time) float64 13kB ...
#     pressure_ebasmetadata                                 (Location, metadata_time) |S64 64B ...
#     temperature_qc                                        (Location, temperature_qc_flags, time) float64 13kB ...
#     temperature_ebasmetadata                              (Location, metadata_time) |S64 64B ...
#     ...                                                    ...
#     aerosol_absorption_coefficient_perc8413_ebasmetadata  (Wavelength, metadata_time) |S64 448B ...
#     pressure                                              (Location, time) float64 13kB ...
#     temperature                                           (Location, time) float64 13kB ...
#     aerosol_absorption_coefficient_amean                  (Wavelength, time) float64 89kB ...
#     aerosol_absorption_coefficient_prec1587               (Wavelength, time) float64 89kB ...
#     aerosol_absorption_coefficient_perc8413               (Wavelength, time) float64 89kB ...
# Attributes: (12/108)
#     Conventions:                        CF-1.8, ACDD-1.3
#     featureType:                        timeSeries
#     title:                              Aerosol_absorption_coefficient at Kos...
#     keywords:                           ACTRIS_NRT, aerosol_absorption_coeffi...
#     id:                                 CZ0003R.20260128110000.20260428111410...
#     naming_authority:                   EBAS
#     ...                                 ...
#     geospatial_lat_units:               degrees_north
#     geospatial_lon_units:               degrees_east
#     comment:                            {\n    "Data definition": "EBAS_1.1",...
#     standard_name_vocabulary:           CF-1.7, ACDD-1.3
#     history:                            None
#     creator_url:                        ebas.nilu.no

# %% [markdown]
# ### Calculate eBC from aerosol absorption coefficient

# %%
# Calculate the closest wavelength to 637.0 nm. This is the wavelength used to calculate eBC.
given_wavelength = 637. 
all_wavelengths = ds_xr.Wavelength.values

closest_wavelength = min(all_wavelengths, key=lambda x:abs(x-given_wavelength))
closest_wavelength
# Out:
# np.float64(660.0)

# %%
# Find the index of the second closest wavelength 
cw_index = np.where(all_wavelengths==closest_wavelength)[0][0]
if closest_wavelength > given_wavelength: 
    scw_index = cw_index-1
    print(all_wavelengths[cw_index], all_wavelengths[scw_index])
elif closest_wavelength < given_wavelength: 
    scw_index = cw_index+1
    print(all_wavelengths[cw_index], all_wavelengths[scw_index])
else: 
    # No need for second closest wavelength as the closest wavelength is 637.0 nm
    scw_index = False
    print(all_wavelengths[cw_index])
# Out:
# 660.0 590.0

# %%
# Create datasets with the aerosol absorption coefficient for the wavelength(s)

ab = ds_xr["aerosol_absorption_coefficient_amean"] 
ab_cw = ab.sel(Wavelength = all_wavelengths[cw_index]) 
if scw_index != False: 
    ab_scw = ab.sel(Wavelength = all_wavelengths[scw_index])
ab_cw
# Out:
# <xarray.DataArray 'aerosol_absorption_coefficient_amean' (time: 1582)> Size: 13kB
# [1582 values with dtype=float64]
# Coordinates:
#   * time        (time) datetime64[ns] 13kB 2026-01-28T11:30:00 ... 2026-04-28...
#     Wavelength  float64 8B 660.0
# Attributes: (12/56)
#     units:                              1/Mm
#     ancillary_variables:                aerosol_absorption_coefficient_amean_...
#     cell_methods:                       time: mean
#     ebas_data_license:                  https://creativecommons.org/licenses/...
#     ebas_revision_date:                 20260428111410
#     ebas_version:                       1
#     ...                                 ...
#     ebas_framework_contact_name:        Cathrine Lund Myhre
#     ebas_framework_contact_email:       clm@nilu.no
#     ebas_originator:                    Roman, Prokeš, prokes.r@czechglobe.cz...
#     ebas_submitter:                     Mbengue, Saliou, mbengue.s@czechglobe...
#     ebas_acknowledgement:               Data used in this <study/report/figur...
#     ebas_comment:                       automatic data processing using 'ebas...

# %%
"""
Calculate Ångström coefficient from the two closest wavelengths and aerosol absorption coefficients to 637.0nm

Parameters:
    sigma1      aerosol absorption coefficient for lambda1
    sigma2      aerosol absorption coefficient for lambda2
    lambda1     wavelength nr. 1
    lambda2     wavelength nr. 2

Returns:
    Ångström coefficient (angstrom_lambda1_lambda2)
"""

def angstrom(sigma1,sigma2,lambda1, lambda2):
    # For a smooth operation, check that datasets are even in size.
    if len(sigma1) == len(sigma2):
        A = len(sigma1)
    else:
        return print("Match length of datasets.")
    
    alpha = np.zeros(A) # empty array with length of dataset
    
    for i in range(A):
        # checking for NaNs and negative numbers
        if np.isnan(sigma1.iloc[i]) or np.isnan(sigma2.iloc[i]):
            alpha[i] = np.nan
        elif sigma1.iloc[i] < 0 or sigma2.iloc[i] < 0:
            alpha[i] = np.nan
        else:
            alpha[i] = (np.log(sigma2.iloc[i]/sigma1.iloc[i]))/(np.log(lambda1/lambda2))
            # checking for Ångström coefficient values outside of the typical range
            if alpha[i] < 0.7:
                alpha[i] = 0.7
            if alpha[i] > 3.0:
                alpha[i] = 3.0

    time = sigma1.index
    return time, alpha

# %%
if scw_index != False: 
    #Create dataframes for plotting
    ab_cw_df = ab_cw.to_dataframe()
    ab_scw_df = ab_scw.to_dataframe()
    lambda_cw = all_wavelengths[cw_index]
    lambda_scw = all_wavelengths[scw_index]

    time, alpha = angstrom(ab_cw_df["aerosol_absorption_coefficient_amean"], ab_scw_df["aerosol_absorption_coefficient_amean"],lambda_cw, lambda_scw)

    # Plot the Ångström exponent 
    plt.figure(figsize=(10,6))
    plt.plot(time, alpha, color='g')
    plt.xticks(rotation=45)
    plt.title("Ångström exponent")
    plt.xlabel("Date")
    plt.ylabel("α")
    plt.gca().set_facecolor('white')
    plt.grid(True, linestyle='--', alpha=0.5)
    text_box_props = dict(boxstyle='round', facecolor='white', alpha=0.5)
    plt.text(0.02, 0.87, 'Particle size. PM10\nWavelengths: 522nm, 660nm', transform=plt.gca().transAxes, bbox=text_box_props)

    plt.show()

# %%
"""
Calculate aerosol absorption coefficients at 637.0nm

Parameters:
    alpha       Ångström exponent
    sigma       Known Aerosol Absorption Coefficient, depending on what you calculated the exponent for.
    lambda_s    Wavelength for sigma
    lambda_a    Wavelength you want to find the coefficient for, here 637.0 nm
    precision   precision (digits)

Returns:
    Aerosol Absorption Coefficients at 637.0nm (abs_coeff)
"""
def calculate_abs_coeff(alpha, sigma, lambda_s, lambda_a):
    abs_coeff = np.zeros(len(alpha))
    for i in range(len(alpha)):
        abs_coeff[i] = ((lambda_a/lambda_s)**(-alpha[i]))*sigma.iloc[i]
    time = sigma.index
    return time, abs_coeff

# %%
if scw_index != False: 
    # Executing the function for deriving absoprtion coefficient at wanted wavelength
    time, abs_coeff637 = calculate_abs_coeff(alpha, ab_cw_df["aerosol_absorption_coefficient_amean"], given_wavelength, lambda_cw)

    df_ab637 = pd.DataFrame(abs_coeff637, time) # making into dataframe
    df_ab637.columns = ["estimated_aerosol_absorption_coefficient"]

    print(df_ab637)
# Out:
#                      estimated_aerosol_absorption_coefficient
# time
# 2026-01-28 11:30:00                                  2.364856
# 2026-01-28 12:30:00                                  3.706283
# 2026-01-28 13:30:00                                  3.020645
# 2026-01-28 14:30:00                                  3.254148
# 2026-01-28 15:30:00                                  3.038032
# ...                                                       ...
# 2026-04-28 06:30:00                                  1.905291
# 2026-04-28 07:30:00                                  1.418425
# 2026-04-28 08:30:00                                  1.060734
# 2026-04-28 09:30:00                                  0.929090
# 2026-04-28 10:30:00                                  0.817351
#
# [1582 rows x 1 columns]

# %%
if scw_index != False:
    # Plot of extrapolated aerosol absorption coefficient at 637.0 nm compared to aerosol absorption coefficient at closest wavelength
    # This is a check that the extrapolation is correct
    fig, ax = plt.subplots(figsize=(10,6))

    ab_cw_df["aerosol_absorption_coefficient_amean"].plot(ax=ax, label="Absorption coefficient, {} nm".format(lambda_cw))
    #ab_scw_df["aerosol_absorption_coefficient_amean"].plot(ax=ax, label="Estimated absorption coefficient, {}nm".format(lambda_scw))
    if scw_index != False: 
        df_ab637["estimated_aerosol_absorption_coefficient"].plot(ax=ax, label="Estimated absorption coefficient, 637 nm")

    plt.title("Estimated absorption coefficient")
    plt.xlabel("Time")
    plt.ylabel("[1/Mm]")

    plt.gca().set_facecolor('white')
    plt.grid(True, linestyle='--', alpha=0.5)

    plt.legend()
    plt.show()

# %%
if scw_index != False: 
    # Convert from dataframe to Data Array with correct wavelength
    da_ab637 = df_ab637.to_xarray().assign_coords({"Wavelength": (637.0)}).estimated_aerosol_absorption_coefficient
elif scw_index == False:
    da_ab637 = ab_cw_df["aerosol_absorption_coefficient_amean"].to_xarray().assign_coords({"Wavelength": (637.0)})
da_ab637
# Out:
# <xarray.DataArray 'estimated_aerosol_absorption_coefficient' (time: 1582)> Size: 13kB
# array([2.36485633, 3.7062828 , 3.02064487, ..., 1.06073386, 0.92909032,
#        0.81735139], shape=(1582,))
# Coordinates:
#   * time        (time) datetime64[ns] 13kB 2026-01-28T11:30:00 ... 2026-04-28...
#     Wavelength  float64 8B 637.0

# %%
# Calculate equivalent black carbon from aerosol absorption coefficient. 
MAC = 10.0 #m2 g-1

da_eBC = (da_ab637/MAC).rename('eBC')

da_eBC
# Out:
# <xarray.DataArray 'eBC' (time: 1582)> Size: 13kB
# array([0.23648563, 0.37062828, 0.30206449, ..., 0.10607339, 0.09290903,
#        0.08173514], shape=(1582,))
# Coordinates:
#   * time        (time) datetime64[ns] 13kB 2026-01-28T11:30:00 ... 2026-04-28...
#     Wavelength  float64 8B 637.0

# %% [markdown]
# ### Plot of equivalent black carbon

# %%
# Convert xarray's DataArray to pandas DataFrame and plot data.
df_eBC = da_eBC.to_dataframe()

fig = px.line(df_eBC.eBC)


station = ds_xr.title.split(" at ", 1)[-1] if " at " in ds_xr.title else ds_xr.title

fig.update_layout(
    title="Equivalent black carbon (eBC) from {0}".format(station),
    xaxis_title="Time",
    yaxis_title="µg/m3 (equivalent black carbon)",
    font=dict(
        family="Courier New, monospace",
        size=11,
        color="RebeccaPurple"
    ),
    legend=dict(
        title='Calculated at {0} nm:'.format(da_eBC.Wavelength.values)
    ),
    width=1500,
    height=500
)
fig.show()

# %% [markdown]
# ### Daily mean

# %%
# resample to daily and monthly mean values
df_day = df_eBC.eBC.resample('D').mean()
df_month = df_eBC.eBC.resample('ME').mean()

# %%
daily_mean = df_day.iloc[-1:].to_dict()

# create variables for daily mean
sample_date_daily_mean = list(daily_mean.keys())[0]
sample_value_daily_mean = round(list(daily_mean.values())[0],6)
print('Daily mean for',sample_date_daily_mean,', eBC =', sample_value_daily_mean, 'µg/m3')
# Out:
# Daily mean for 2026-04-28 00:00:00 , eBC = 0.138481 µg/m3

# %% [markdown]
# ### Monthly mean

# %%
monthly_mean = df_month.iloc[-2:-1].to_dict()

# create variables for monthly mean
sample_date_monthly_mean = list(monthly_mean.keys())[0]
sample_value_monthly_mean = round(list(monthly_mean.values())[0],6)
print('Monthly mean for',sample_date_monthly_mean.month_name(),', eBC =', sample_value_monthly_mean, 'µg/m3')
# Out:
# Monthly mean for March , eBC = 0.315219 µg/m3

# %% [markdown]
# ### Last 3 months

# %%
last3months = statistics.mean(list(df_month.to_dict().values())[0:3])

# create variables for daily mean
sample_date_last3months_mean = list(df_month.to_dict().keys())
sample_value_last3months_mean = round(last3months,6)

sample_date_last3months_mean = "{0} - {1}".format(sample_date_last3months_mean[0].month_name(),sample_date_last3months_mean[2].month_name())

print('Last 3 months (',sample_date_last3months_mean,'), eBC =', sample_value_last3months_mean, 'µg/m3')
# Out:
# Last 3 months ( January - March ), eBC = 0.428054 µg/m3
